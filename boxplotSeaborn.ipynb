# %%
import pandas as pd
import seaborn as srn

# %%
tree = pd.read_csv('trees.csv')
tree

# %%
#Visualização de um boxplot
#parâmetro 'orient' para mudar a orientação do gráfico
#V para vertical e H para orizontal
srn.boxplot(data=tree.Volume, orient='v').set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
#Visualizando varios boxplot na mesma imagem
srn.boxplot(data = tree)
# Out:
# <Axes: >
