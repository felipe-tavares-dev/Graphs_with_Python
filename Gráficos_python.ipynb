# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("/content/trees.csv")
dados.shape
# Out:
# (31, 3)

# %%
histograma = np.histogram(dados.iloc[:,1], bins=6)
histograma
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
plt.hist(dados.iloc[:,1])
plt.title('Ávores')
plt.ylabel("Árvores")
plt.xlabel('Frequência')
# Out:
# Text(0.5, 0, 'Frequência')
